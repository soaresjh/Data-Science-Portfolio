# %%
# %run pre_process.py data registration.csv
# Out:
# -------> INITIALIZING <-------
# LOADING  - ......................................................
# FILE NAME
# ----> data/registration.csv <----
#  - raw dataframe
# Missing Features:
# - ['Cabin', 687]
# - ['Age', 177]
# - ['Embarked', 2]
#
# Object Features:
# - ['Name', 891]
# - ['Ticket', 681]
# - ['Cabin', 148]
# - ['Embarked', 4]
# - ['Sex', 2]
# PROCESSING  - ...................................................
#   - Age - .......................................................
#   - Fare - ......................................................
#   - Embarker - ..................................................
#   - Cabin - .....................................................
#   - Title - .....................................................
#   - Sex - .......................................................
#   - Ticket - ....................................................
# *TICKET COLUMN IS BEING DROPED
# ...

# %%
# %run cabin_classify.py data registration.csv md0718_H1618
# Out:
# LOADING  - ......................................................
# FILE NAME
# ----> data/md0718_H1618_pre_feat_registration.csv <----
# MODELING  - .....................................................
# PREDICTING  - ...................................................
# SAVING  - .......................................................
# DONE!!!
# FILE NAME
# ----> md0718_H1618_features_registration.csv <----

# %%
# %matplotlib inline
# %run train_and_test.py data registration.csv md0718_H1618
# Out:
# LOADING  - ......................................................
# FILES NAME
# ----> data/md0718_H1618_features_registration.csv <----
# ----> data/md0718_H1618_target_registration.csv   <----
# MODELING ........................................................
#  - Train/Test Spliting ..........................................
#  -- Training Model ..............................................
# EVALUATING ......................................................
# Area Under the Curve = 0.841
# SAVING MODEL ....................................................
# model Directory already existent
# DONE!!!
# MODEL NAME
# ----> model/trained_model_md0718_H1618_registration.pkl <----
