# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

# %%
from pywasp.metrics import plot_roc_auc, plot_confusion_matrix

# %%
y_test = []
with open('y_test.txt', 'r') as f:
    for v in f.read().split('\n'):
        try:
            y_test.append(float(v))
        except:
            None
y_prob = []
with open('y_prob.txt', 'r') as f:
    for v in f.read().split('\n'):
        try:
            y_prob.append(float(v))
        except:
            None
y_pred = []
with open('y_pred.txt', 'r') as f:
    for v in f.read().split('\n'):
        try:
            y_pred.append(float(v))
        except:
            None

# %%
plot_roc_auc(y_test,y_prob)
# Out:
# (0.9498521088363161, <Figure size 576x360 with 2 Axes>)

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plot_confusion_matrix(cm, )
